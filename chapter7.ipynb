# %% [markdown]
# # 7. フーリエ変換の諸性質

# %% [markdown]
# ## 章末問題

# %%
# 7.56
import numpy as np
import matplotlib.pyplot as plt

N = 20
t = np.arange(-5, 5, 0.001)
x = np.sin((N + 0.5) * t) / np.sin(t/2)
plt.plot(t, x)
plt.xlabel(r"$\theta$", fontsize=18)
plt.ylabel("D", fontsize=18)
plt.show()
